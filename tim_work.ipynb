# %%
# from IPython.core.interactiveshell import InteractiveShell  
# InteractiveShell.ast_node_interactivity = "all"

# %%
#import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# importing the necessary packages
import pandas as pd
# import pandas_profiling
df = pd.read_excel(r"C:\Users\cesma\Desktop\Dati TIM\03_customer experience\dataset_assurance.xlsx", sheet_name=0)

# %%
df.head()
# Out:
#                            ID_INTERVISTATO  DATA_INT AMBITO  \
# 0  6285_9_000263704728020d84b32a1541409a32   8012018  Fisso
# 1  6285_9_0007c2e6e4d81ac8a4750d2016e422aa  23012018  Fisso
# 2  6285_9_000d02ec9700a742fd6551bb89486772  16012018  Fisso
# 3  6285_9_001e5f61be3f4609b5bb762fa28789d2  22012018  Fisso
# 4  6285_9_00363cec236500c05b2e112144ccf590  13012018  Fisso
#
#                   AOL BACINO_ACCOGLIENZA      CAUSALE_TT     COMUNE_IMPIANTO  \
# 0                  S1                IVR  Non Scorporato               FORIO
# 1                Roma                IVR  Non Scorporato                ROMA
# 2           AOL_LAZIO                IVR  Non Scorporato  ANGUILLARA SABAZIA
# 3      AOL_BASILICATA             Abramo  Non Scorporato             LAVELLO
# 4  AOL_LOM_CENTRO_EST                 LO  Non Scorporato  CASSINA DE' PECCHI
#
#       DATA_APERTURA_TT     DATA_CHIUSURA_TT                      DESC_GUASTO  \
# ...

# %%
OVS10 = df[["ID_INTERVISTATO", "OVS_1_6_10"]]

# %%
OVS10.head()
# Out:
#                            ID_INTERVISTATO  \
# 0  6285_9_000263704728020d84b32a1541409a32
# 1  6285_9_0007c2e6e4d81ac8a4750d2016e422aa
# 2  6285_9_000d02ec9700a742fd6551bb89486772
# 3  6285_9_001e5f61be3f4609b5bb762fa28789d2
# 4  6285_9_00363cec236500c05b2e112144ccf590
#
#                                           OVS_1_6_10
# 0                                                NaN
# 1                                                NaN
# 2  Ho segnalato l'impossibilità di utilizzare tim...
# 3                                                NaN
# 4  Il tecnico che ha installato la fibra ha sbagl...

# %%
OVS10.shape
# Out:
# (10822, 2)

# %%
OVS10_clean = OVS10.dropna()
OVS10_clean.head()
# Out:
#                             ID_INTERVISTATO  \
# 2   6285_9_000d02ec9700a742fd6551bb89486772
# 4   6285_9_00363cec236500c05b2e112144ccf590
# 41  6285_9_01d25ed2134d651ef76121b44d20beae
# 61  6285_9_02e202d53be7775803819470a35e4075
# 84  6285_9_03dd1d1069a1dc7e568ec2f63f13b720
#
#                                            OVS_1_6_10
# 2   Ho segnalato l'impossibilità di utilizzare tim...
# 4   Il tecnico che ha installato la fibra ha sbagl...
# 41  Ho più volte segnalato dei disservizi anche vi...
# 61  L'operatore che mi ha contattato il 31/01/18 a...
# 84  Ho fatto oltre 50 chiamate al 187 da giugno/lu...

# %%
OVS10_clean.to_csv("OVS10_clean.csv")

# %%
# from pprint import pprint  # pretty-printer
# from collections import defaultdict

# %%
# pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
#profile = pandas_profiling.ProfileReport(df)
#profile.to_file(outputfile="Customer_Experience_Exploration.html")
